# %%
import pandas as pd
from datetime import datetime

folder = "./data/20210921/"

# %%
dfp_train = pd.read_csv(folder + "train.csv")
dfp_test = pd.read_csv(folder + "test.csv")
print(len(dfp_train))

dfp_mapping = pd.read_csv("./data/train_breath_mapping.csv")
dfp_train = pd.merge(dfp_train, dfp_mapping[dfp_mapping["type_record"] == "training"]["breath_id"], on=["breath_id"])
print(len(dfp_train))

dfp_train.sort_values(["breath_id", "time_step"], inplace=True)
dfp_test.sort_values(["breath_id", "time_step"], inplace=True)
# Out:
# 6036000
# 4828800

# %%
#
folder_cluster = "./data/clusters/"
clusters_type = ["cluster_ed","cluster_dtw"]
for cluster_type in clusters_type:
    dfp_assignations = pd.read_csv(folder_cluster + f"train_{cluster_type}_assignations.csv")
    del dfp_assignations["Unnamed: 0"]
    dfp_assignations = dfp_assignations[["breath_id", "closest_cluster"]]
    dfp_assignations["closest_cluster"] = dfp_assignations["closest_cluster"].astype(str)
    dfp_assignations.columns = ["breath_id", f"closest_cluster_{cluster_type}"]
    dfp_train = pd.merge(dfp_train, dfp_assignations, on=["breath_id"])
    

for cluster_type in clusters_type:
    dfp_assignations = pd.read_csv(folder_cluster + f"test_{cluster_type}_assignations.csv")
    del dfp_assignations["Unnamed: 0"]
    dfp_assignations = dfp_assignations[["breath_id", "closest_cluster"]]
    dfp_assignations["closest_cluster"] = dfp_assignations["closest_cluster"].astype(str)
    dfp_assignations.columns = ["breath_id", f"closest_cluster_{cluster_type}"]
    dfp_test = pd.merge(dfp_test, dfp_assignations, on=["breath_id"])

# %%
dfp_train.iloc[0]
# Out:
# id                                    1
# breath_id                             1
# R                                    20
# C                                    50
# time_step                           0.0
# u_in                           0.083334
# u_out                                 0
# pressure                       5.837492
# closest_cluster_cluster_ed            3
# closest_cluster_cluster_dtw          31
# Name: 0, dtype: object

# %% [markdown]
# ## GEt kaggle features

# %%
# From https://www.kaggle.com/tenffe/finetune-of-tensorflow-bidirectional-lstm
def add_features(df):
    df['area'] = df['time_step'] * df['u_in']
    df['area'] = df.groupby('breath_id')['area'].cumsum()
    df['u_in_cumsum'] = (df['u_in']).groupby(df['breath_id']).cumsum()
    df['u_in_lag1'] = df.groupby('breath_id')['u_in'].shift(1)
    df['u_out_lag1'] = df.groupby('breath_id')['u_out'].shift(1)
    df['u_in_lag_back1'] = df.groupby('breath_id')['u_in'].shift(-1)
    df['u_out_lag_back1'] = df.groupby('breath_id')['u_out'].shift(-1)
    df['u_in_lag2'] = df.groupby('breath_id')['u_in'].shift(2)
    df['u_out_lag2'] = df.groupby('breath_id')['u_out'].shift(2)
    df['u_in_lag_back2'] = df.groupby('breath_id')['u_in'].shift(-2)
    df['u_out_lag_back2'] = df.groupby('breath_id')['u_out'].shift(-2)
    df['u_in_lag3'] = df.groupby('breath_id')['u_in'].shift(3)
    df['u_out_lag3'] = df.groupby('breath_id')['u_out'].shift(3)
    df['u_in_lag_back3'] = df.groupby('breath_id')['u_in'].shift(-3)
    df['u_out_lag_back3'] = df.groupby('breath_id')['u_out'].shift(-3)
    df['u_in_lag4'] = df.groupby('breath_id')['u_in'].shift(4)
    df['u_out_lag4'] = df.groupby('breath_id')['u_out'].shift(4)
    df['u_in_lag_back4'] = df.groupby('breath_id')['u_in'].shift(-4)
    df['u_out_lag_back4'] = df.groupby('breath_id')['u_out'].shift(-4)
    df = df.fillna(0)
    df['breath_id__u_in__max'] = df.groupby(['breath_id'])['u_in'].transform('max')
    df['breath_id__u_out__max'] = df.groupby(['breath_id'])['u_out'].transform('max')
    df['u_in_diff1'] = df['u_in'] - df['u_in_lag1']
    df['u_out_diff1'] = df['u_out'] - df['u_out_lag1']
    df['u_in_diff2'] = df['u_in'] - df['u_in_lag2']
    df['u_out_diff2'] = df['u_out'] - df['u_out_lag2']
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    df['u_in_diff3'] = df['u_in'] - df['u_in_lag3']
    df['u_out_diff3'] = df['u_out'] - df['u_out_lag3']
    df['u_in_diff4'] = df['u_in'] - df['u_in_lag4']
    df['u_out_diff4'] = df['u_out'] - df['u_out_lag4']
    df['cross']= df['u_in']*df['u_out']
    df['cross2']= df['time_step']*df['u_out']
    df['R'] = df['R'].astype(str)
    df['C'] = df['C'].astype(str)
    df['R__C'] = df["R"].astype(str) + '__' + df["C"].astype(str)
#     df = pd.get_dummies(df)
    return df

# %%
# %%time
dfp_train_augmented = add_features(dfp_train)
dfp_test_augmented = add_features(dfp_test)
# Out:
# CPU times: user 12.7 s, sys: 1.56 s, total: 14.2 s
# Wall time: 14.2 s

# %%
dfp_train_augmented.iloc[0]
# Out:
# id                                     1
# breath_id                              1
# R                                     20
# C                                     50
# time_step                            0.0
# u_in                            0.083334
# u_out                                  0
# pressure                        5.837492
# closest_cluster_cluster_ed             3
# closest_cluster_cluster_dtw           31
# area                                 0.0
# u_in_cumsum                     0.083334
# u_in_lag1                            0.0
# u_out_lag1                           0.0
# u_in_lag_back1                 18.383041
# u_out_lag_back1                      0.0
# u_in_lag2                            0.0
# u_out_lag2                           0.0
# u_in_lag_back2                 22.509278
# u_out_lag_back2                      0.0
# u_in_lag3                            0.0
# u_out_lag3                           0.0
# u_in_lag_back3                 22.808822
# u_out_lag_back3                      0.0
# u_in_lag4                            0.0
# u_out_lag4                           0.0
# u_in_lag_back4                  25.35585
# u_out_lag_back4                      0.0
# breath_id__u_in__max           28.313036
# breath_id__u_out__max                  1
# u_in_diff1                      0.083334
# u_out_diff1                          0.0
# u_in_diff2                      0.083334
# u_out_diff2                          0.0
# breath_id__u_in__diffmax       28.229702
# breath_id__u_in__diffmean      10.062673
# u_in_diff3                      0.083334
# u_out_diff3                          0.0
# u_in_diff4                      0.083334
# u_out_diff4                          0.0
# cross                                0.0
# cross2                               0.0
# R__C                              20__50
# Name: 0, dtype: object

# %%
column_target = "pressure"
metric = "mae"

columns_features = []
for elt in list(dfp_train_augmented.columns):
    if elt not in ["id", "breath_id", "pressure"]:
        columns_features.append(elt)
        
print("Features:", columns_features)

X_train, y_train = dfp_train_augmented[columns_features], dfp_train_augmented[column_target]
X_test = dfp_test_augmented.sort_values("id")[columns_features]
# Out:
# Features: ['R', 'C', 'time_step', 'u_in', 'u_out', 'closest_cluster_cluster_ed', 'closest_cluster_cluster_dtw', 'area', 'u_in_cumsum', 'u_in_lag1', 'u_out_lag1', 'u_in_lag_back1', 'u_out_lag_back1', 'u_in_lag2', 'u_out_lag2', 'u_in_lag_back2', 'u_out_lag_back2', 'u_in_lag3', 'u_out_lag3', 'u_in_lag_back3', 'u_out_lag_back3', 'u_in_lag4', 'u_out_lag4', 'u_in_lag_back4', 'u_out_lag_back4', 'breath_id__u_in__max', 'breath_id__u_out__max', 'u_in_diff1', 'u_out_diff1', 'u_in_diff2', 'u_out_diff2', 'breath_id__u_in__diffmax', 'breath_id__u_in__diffmean', 'u_in_diff3', 'u_out_diff3', 'u_in_diff4', 'u_out_diff4', 'cross', 'cross2', 'R__C']

# %%
# from supervised.automl import AutoML

# for mode in ["Compete"]:
#     dfp_submissions = dfp_test_augmented.sort_values("id").copy()
#     automl = AutoML(mode=mode, eval_metric=metric)
#     automl.fit(X_train, y_train)

#     dfp_submissions["pressure"] = automl.predict(X_test)
#     dfp_submissions = dfp_submissions[["id", "pressure"]]
#     dfp_submissions.to_csv(f"./data/submissions/{datetime.utcnow().strftime('%Y%m%d%H')}_mljar_{mode.lower()}_with_closest_cluster_wo_dummies.csv", index=None)

# %%
from flaml import AutoML

metric = "mae"
time_budget = 3 * 3600

automl_settings = {
    "time_budget": time_budget,  # in seconds
    "metric": metric,
    "task": "regression",
    "log_file_name": f"flaml_{time_budget}_nf20211028_{metric}.log",
}

dfp_submissions = dfp_test_augmented.sort_values("id").copy()
automl = AutoML()
automl.fit(X_train=X_train, y_train=y_train, **automl_settings)

dfp_submissions["pressure"] = automl.predict(X_test)
dfp_submissions = dfp_submissions[["id", "pressure"]]
dfp_submissions.to_csv(f"./data/submissions/{datetime.utcnow().strftime('%Y%m%d%H')}_flaml{time_budget}_with_closest_cluster_wo_dummies.csv", index=None)
# Out:
# [flaml.automl: 10-28 13:52:10] {1432} INFO - Evaluation method: holdout
# [flaml.automl: 10-28 13:52:16] {1478} INFO - Minimizing error metric: mae
# [flaml.automl: 10-28 13:52:16] {1515} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'catboost', 'xgboost', 'extra_tree']
# [flaml.automl: 10-28 13:52:16] {1748} INFO - iteration 0, current learner lgbm
# [flaml.automl: 10-28 13:52:16] {1866} INFO - Estimated sufficient time budget=1123580s. Estimated necessary time budget=2416s.
# [flaml.automl: 10-28 13:52:16] {1944} INFO -  at 60.7s,	estimator lgbm's best error=4.5014,	best estimator lgbm's best error=4.5014
# [flaml.automl: 10-28 13:52:16] {1748} INFO - iteration 1, current learner lgbm
# [flaml.automl: 10-28 13:52:16] {1944} INFO -  at 60.9s,	estimator lgbm's best error=4.5014,	best estimator lgbm's best error=4.5014
# [flaml.automl: 10-28 13:52:16] {1748} INFO - iteration 2, current learner lgbm
# [flaml.automl: 10-28 13:52:16] {1944} INFO -  at 61.1s,	estimator lgbm's best error=3.0438,	best estimator lgbm's best error=3.0438
# [flaml.automl: 10-28 13:52:16] {1748} INFO - iteration 3, current learner lgbm
# [flaml.automl: 10-28 13:52:17] {1944} INFO -  at 61.4s,	estimator lgbm's best error=1.9677,	best estimator lgbm's best error=1.9677
# [flaml.automl: 10-28 13:52:17] {1748} INFO - iteration 4, current learner lgbm
# [flaml.automl: 10-28 13:52:17] {1944} INFO -  at 61.6s,	estimator lgbm's best error=1.9677,	best estimator lgbm's best error=1.9677
# [flaml.automl: 10-28 13:52:17] {1748} INFO - iteration 5, current learner lgbm
# [flaml.automl: 10-28 13:52:17] {1944} INFO -  at 61.8s,	estimator lgbm's best error=1.7687,	best estimator lgbm's best error=1.7687
# [flaml.automl: 10-28 13:52:17] {1748} INFO - iteration 6, current learner xgboost
# [flaml.automl: 10-28 13:52:17] {1944} INFO -  at 62.1s,	estimator xgboost's best error=7.0415,	best estimator lgbm's best error=1.7687
# [flaml.automl: 10-28 13:52:17] {1748} INFO - iteration 7, current learner lgbm
# [flaml.automl: 10-28 13:52:18] {1944} INFO -  at 62.3s,	estimator lgbm's best error=1.7687,	best estimator lgbm's best error=1.7687
# [flaml.automl: 10-28 13:52:18] {1748} INFO - iteration 8, current learner lgbm
# [flaml.automl: 10-28 13:52:18] {1944} INFO -  at 62.5s,	estimator lgbm's best error=1.7687,	best estimator lgbm's best error=1.7687
# [flaml.automl: 10-28 13:52:18] {1748} INFO - iteration 9, current learner lgbm
# [flaml.automl: 10-28 13:52:18] {1944} INFO -  at 62.8s,	estimator lgbm's best error=1.4802,	best estimator lgbm's best error=1.4802
# [flaml.automl: 10-28 13:52:18] {1748} INFO - iteration 10, current learner xgboost
# [flaml.automl: 10-28 13:52:18] {1944} INFO -  at 63.0s,	estimator xgboost's best error=7.0415,	best estimator lgbm's best error=1.4802
# [flaml.automl: 10-28 13:52:18] {1748} INFO - iteration 11, current learner extra_tree
# [flaml.automl: 10-28 13:52:19] {1944} INFO -  at 63.5s,	estimator extra_tree's best error=2.6968,	best estimator lgbm's best error=1.4802
# [flaml.automl: 10-28 13:52:19] {1748} INFO - iteration 12, current learner xgboost
# [flaml.automl: 10-28 13:52:19] {1944} INFO -  at 63.8s,	estimator xgboost's best error=3.5795,	best estimator lgbm's best error=1.4802
# [flaml.automl: 10-28 13:52:19] {1748} INFO - iteration 13, current learner xgboost
# [flaml.automl: 10-28 13:52:19] {1944} INFO -  at 64.0s,	estimator xgboost's best error=2.2412,	best estimator lgbm's best error=1.4802
# [flaml.automl: 10-28 13:52:19] {1748} INFO - iteration 14, current learner xgboost
# [flaml.automl: 10-28 13:52:19] {1944} INFO -  at 64.3s,	estimator xgboost's best error=2.2412,	best estimator lgbm's best error=1.4802
# [flaml.automl: 10-28 13:52:19] {1748} INFO - iteration 15, current learner lgbm
# [flaml.automl: 10-28 13:52:20] {1944} INFO -  at 64.5s,	estimator lgbm's best error=1.4802,	best estimator lgbm's best error=1.4802
# [flaml.automl: 10-28 13:52:20] {1748} INFO - iteration 16, current learner extra_tree
# [flaml.automl: 10-28 13:52:20] {1944} INFO -  at 64.9s,	estimator extra_tree's best error=1.9205,	best estimator lgbm's best error=1.4802
# [flaml.automl: 10-28 13:52:20] {1748} INFO - iteration 17, current learner lgbm
# [flaml.automl: 10-28 13:52:21] {1944} INFO -  at 65.8s,	estimator lgbm's best error=0.9181,	best estimator lgbm's best error=0.9181
# [flaml.automl: 10-28 13:52:21] {1748} INFO - iteration 18, current learner rf
# [flaml.automl: 10-28 13:52:21] {1944} INFO -  at 66.3s,	estimator rf's best error=2.4240,	best estimator lgbm's best error=0.9181
# [flaml.automl: 10-28 13:52:21] {1748} INFO - iteration 19, current learner xgboost
# [flaml.automl: 10-28 13:52:22] {1944} INFO -  at 66.5s,	estimator xgboost's best error=2.2412,	best estimator lgbm's best error=0.9181
# [flaml.automl: 10-28 13:52:22] {1748} INFO - iteration 20, current learner rf
# [flaml.automl: 10-28 13:52:22] {1944} INFO -  at 67.1s,	estimator rf's best error=1.7381,	best estimator lgbm's best error=0.9181
# [flaml.automl: 10-28 13:52:22] {1748} INFO - iteration 21, current learner xgboost
# [flaml.automl: 10-28 13:52:22] {1944} INFO -  at 67.3s,	estimator xgboost's best error=1.9216,	best estimator lgbm's best error=0.9181
# [flaml.automl: 10-28 13:52:22] {1748} INFO - iteration 22, current learner lgbm
# [flaml.automl: 10-28 13:52:24] {1944} INFO -  at 68.4s,	estimator lgbm's best error=0.9181,	best estimator lgbm's best error=0.9181
# [flaml.automl: 10-28 13:52:24] {1748} INFO - iteration 23, current learner lgbm
# [flaml.automl: 10-28 13:52:24] {1944} INFO -  at 69.1s,	estimator lgbm's best error=0.9181,	best estimator lgbm's best error=0.9181
# [flaml.automl: 10-28 13:52:24] {1748} INFO - iteration 24, current learner extra_tree
# [flaml.automl: 10-28 13:52:25] {1944} INFO -  at 69.5s,	estimator extra_tree's best error=1.9205,	best estimator lgbm's best error=0.9181
# [flaml.automl: 10-28 13:52:25] {1748} INFO - iteration 25, current learner extra_tree
# [flaml.automl: 10-28 13:52:25] {1944} INFO -  at 70.2s,	estimator extra_tree's best error=1.4309,	best estimator lgbm's best error=0.9181
# [flaml.automl: 10-28 13:52:25] {1748} INFO - iteration 26, current learner rf
# [flaml.automl: 10-28 13:52:26] {1944} INFO -  at 70.7s,	estimator rf's best error=1.7381,	best estimator lgbm's best error=0.9181
# [flaml.automl: 10-28 13:52:26] {1748} INFO - iteration 27, current learner xgboost
# [flaml.automl: 10-28 13:52:26] {1944} INFO -  at 70.9s,	estimator xgboost's best error=1.7995,	best estimator lgbm's best error=0.9181
# [flaml.automl: 10-28 13:52:26] {1748} INFO - iteration 28, current learner extra_tree
# [flaml.automl: 10-28 13:52:27] {1944} INFO -  at 71.5s,	estimator extra_tree's best error=1.0953,	best estimator lgbm's best error=0.9181
# [flaml.automl: 10-28 13:52:27] {1748} INFO - iteration 29, current learner extra_tree
# [flaml.automl: 10-28 13:52:27] {1944} INFO -  at 72.2s,	estimator extra_tree's best error=1.0953,	best estimator lgbm's best error=0.9181
# [flaml.automl: 10-28 13:52:27] {1748} INFO - iteration 30, current learner lgbm
# [flaml.automl: 10-28 13:52:28] {1944} INFO -  at 72.9s,	estimator lgbm's best error=0.9181,	best estimator lgbm's best error=0.9181
# [flaml.automl: 10-28 13:52:28] {1748} INFO - iteration 31, current learner lgbm
# [flaml.automl: 10-28 13:52:29] {1944} INFO -  at 73.8s,	estimator lgbm's best error=0.8445,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:29] {1748} INFO - iteration 32, current learner lgbm
# [flaml.automl: 10-28 13:52:31] {1944} INFO -  at 75.4s,	estimator lgbm's best error=0.8445,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:31] {1748} INFO - iteration 33, current learner extra_tree
# [flaml.automl: 10-28 13:52:31] {1944} INFO -  at 76.0s,	estimator extra_tree's best error=0.9617,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:31] {1748} INFO - iteration 34, current learner lgbm
# [flaml.automl: 10-28 13:52:32] {1944} INFO -  at 76.7s,	estimator lgbm's best error=0.8445,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:32] {1748} INFO - iteration 35, current learner rf
# [flaml.automl: 10-28 13:52:32] {1944} INFO -  at 77.3s,	estimator rf's best error=1.3535,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:32] {1748} INFO - iteration 36, current learner extra_tree
# [flaml.automl: 10-28 13:52:33] {1944} INFO -  at 77.9s,	estimator extra_tree's best error=0.9617,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:33] {1748} INFO - iteration 37, current learner rf
# [flaml.automl: 10-28 13:52:34] {1944} INFO -  at 78.5s,	estimator rf's best error=1.0655,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:34] {1748} INFO - iteration 38, current learner rf
# [flaml.automl: 10-28 13:52:34] {1944} INFO -  at 79.1s,	estimator rf's best error=1.0655,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:34] {1748} INFO - iteration 39, current learner rf
# [flaml.automl: 10-28 13:52:35] {1944} INFO -  at 79.8s,	estimator rf's best error=0.9826,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:35] {1748} INFO - iteration 40, current learner xgboost
# [flaml.automl: 10-28 13:52:35] {1944} INFO -  at 80.0s,	estimator xgboost's best error=1.5419,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:35] {1748} INFO - iteration 41, current learner extra_tree
# [flaml.automl: 10-28 13:52:36] {1944} INFO -  at 80.8s,	estimator extra_tree's best error=0.8891,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:36] {1748} INFO - iteration 42, current learner lgbm
# [flaml.automl: 10-28 13:52:37] {1944} INFO -  at 82.2s,	estimator lgbm's best error=0.8445,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:37] {1748} INFO - iteration 43, current learner extra_tree
# [flaml.automl: 10-28 13:52:38] {1944} INFO -  at 82.8s,	estimator extra_tree's best error=0.8891,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:38] {1748} INFO - iteration 44, current learner extra_tree
# [flaml.automl: 10-28 13:52:39] {1944} INFO -  at 83.4s,	estimator extra_tree's best error=0.8891,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:39] {1748} INFO - iteration 45, current learner xgboost
# [flaml.automl: 10-28 13:52:39] {1944} INFO -  at 83.7s,	estimator xgboost's best error=1.1782,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:39] {1748} INFO - iteration 46, current learner xgboost
# [flaml.automl: 10-28 13:52:39] {1944} INFO -  at 83.9s,	estimator xgboost's best error=1.1782,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:39] {1748} INFO - iteration 47, current learner xgboost
# [flaml.automl: 10-28 13:52:39] {1944} INFO -  at 84.1s,	estimator xgboost's best error=1.1782,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:39] {1748} INFO - iteration 48, current learner lgbm
# [flaml.automl: 10-28 13:52:40] {1944} INFO -  at 85.1s,	estimator lgbm's best error=0.8445,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:40] {1748} INFO - iteration 49, current learner xgboost
# [flaml.automl: 10-28 13:52:41] {1944} INFO -  at 85.4s,	estimator xgboost's best error=1.0182,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:41] {1748} INFO - iteration 50, current learner extra_tree
# [flaml.automl: 10-28 13:52:41] {1944} INFO -  at 86.1s,	estimator extra_tree's best error=0.8891,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:41] {1748} INFO - iteration 51, current learner rf
# [flaml.automl: 10-28 13:52:42] {1944} INFO -  at 86.7s,	estimator rf's best error=0.9826,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:42] {1748} INFO - iteration 52, current learner rf
# [flaml.automl: 10-28 13:52:43] {1944} INFO -  at 87.5s,	estimator rf's best error=0.9263,	best estimator lgbm's best error=0.8445
# [flaml.automl: 10-28 13:52:43] {1748} INFO - iteration 53, current learner lgbm
# [flaml.automl: 10-28 13:52:44] {1944} INFO -  at 88.8s,	estimator lgbm's best error=0.7313,	best estimator lgbm's best error=0.7313
# [flaml.automl: 10-28 13:52:44] {1748} INFO - iteration 54, current learner lgbm
# [flaml.automl: 10-28 13:52:44] {1944} INFO -  at 89.3s,	estimator lgbm's best error=0.7313,	best estimator lgbm's best error=0.7313
# [flaml.automl: 10-28 13:52:44] {1748} INFO - iteration 55, current learner xgboost
# [flaml.automl: 10-28 13:52:45] {1944} INFO -  at 89.6s,	estimator xgboost's best error=1.0182,	best estimator lgbm's best error=0.7313
# [flaml.automl: 10-28 13:52:45] {1748} INFO - iteration 56, current learner lgbm
# [flaml.automl: 10-28 13:52:48] {1944} INFO -  at 92.8s,	estimator lgbm's best error=0.7257,	best estimator lgbm's best error=0.7257
# [flaml.automl: 10-28 13:52:48] {1748} INFO - iteration 57, current learner lgbm
# [flaml.automl: 10-28 13:52:52] {1944} INFO -  at 96.9s,	estimator lgbm's best error=0.6932,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:52:52] {1748} INFO - iteration 58, current learner catboost
# [flaml.automl: 10-28 13:52:54] {1944} INFO -  at 98.5s,	estimator catboost's best error=0.9434,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:52:54] {1748} INFO - iteration 59, current learner catboost
# [flaml.automl: 10-28 13:52:57] {1944} INFO -  at 101.6s,	estimator catboost's best error=0.9434,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:52:57] {1748} INFO - iteration 60, current learner lgbm
# [flaml.automl: 10-28 13:53:00] {1944} INFO -  at 104.8s,	estimator lgbm's best error=0.6932,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:00] {1748} INFO - iteration 61, current learner catboost
# [flaml.automl: 10-28 13:53:01] {1944} INFO -  at 106.2s,	estimator catboost's best error=0.9331,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:01] {1748} INFO - iteration 62, current learner lgbm
# [flaml.automl: 10-28 13:53:06] {1944} INFO -  at 110.9s,	estimator lgbm's best error=0.6932,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:06] {1748} INFO - iteration 63, current learner xgboost
# [flaml.automl: 10-28 13:53:06] {1944} INFO -  at 111.3s,	estimator xgboost's best error=1.0182,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:06] {1748} INFO - iteration 64, current learner xgboost
# [flaml.automl: 10-28 13:53:07] {1944} INFO -  at 111.5s,	estimator xgboost's best error=1.0182,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:07] {1748} INFO - iteration 65, current learner lgbm
# [flaml.automl: 10-28 13:53:11] {1944} INFO -  at 115.6s,	estimator lgbm's best error=0.6932,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:11] {1748} INFO - iteration 66, current learner rf
# [flaml.automl: 10-28 13:53:12] {1944} INFO -  at 116.5s,	estimator rf's best error=0.9263,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:12] {1748} INFO - iteration 67, current learner xgboost
# [flaml.automl: 10-28 13:53:12] {1944} INFO -  at 116.9s,	estimator xgboost's best error=1.0182,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:12] {1748} INFO - iteration 68, current learner rf
# [flaml.automl: 10-28 13:53:13] {1944} INFO -  at 117.5s,	estimator rf's best error=0.9263,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:13] {1748} INFO - iteration 69, current learner lgbm
# [flaml.automl: 10-28 13:53:20] {1944} INFO -  at 125.1s,	estimator lgbm's best error=0.6932,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:20] {1748} INFO - iteration 70, current learner xgboost
# [flaml.automl: 10-28 13:53:21] {1944} INFO -  at 125.4s,	estimator xgboost's best error=0.9666,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:21] {1748} INFO - iteration 71, current learner xgboost
# [flaml.automl: 10-28 13:53:21] {1944} INFO -  at 125.7s,	estimator xgboost's best error=0.9666,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:21] {1748} INFO - iteration 72, current learner xgboost
# [flaml.automl: 10-28 13:53:22] {1944} INFO -  at 126.3s,	estimator xgboost's best error=0.8630,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:22] {1748} INFO - iteration 73, current learner extra_tree
# [flaml.automl: 10-28 13:53:22] {1944} INFO -  at 127.0s,	estimator extra_tree's best error=0.8891,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:22] {1748} INFO - iteration 74, current learner xgboost
# [flaml.automl: 10-28 13:53:22] {1944} INFO -  at 127.3s,	estimator xgboost's best error=0.8630,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:22] {1748} INFO - iteration 75, current learner extra_tree
# [flaml.automl: 10-28 13:53:24] {1944} INFO -  at 128.4s,	estimator extra_tree's best error=0.8396,	best estimator lgbm's best error=0.6932
# [flaml.automl: 10-28 13:53:24] {1748} INFO - iteration 76, current learner lgbm
# [flaml.automl: 10-28 13:53:29] {1944} INFO -  at 134.2s,	estimator lgbm's best error=0.6304,	best estimator lgbm's best error=0.6304
# [flaml.automl: 10-28 13:53:29] {1748} INFO - iteration 77, current learner lgbm
# [flaml.automl: 10-28 13:53:41] {1944} INFO -  at 145.7s,	estimator lgbm's best error=0.5733,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:53:41] {1748} INFO - iteration 78, current learner xgboost
# [flaml.automl: 10-28 13:53:44] {1944} INFO -  at 148.9s,	estimator xgboost's best error=0.6750,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:53:44] {1748} INFO - iteration 79, current learner xgboost
# [flaml.automl: 10-28 13:53:46] {1944} INFO -  at 150.7s,	estimator xgboost's best error=0.6750,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:53:46] {1748} INFO - iteration 80, current learner lgbm
# [flaml.automl: 10-28 13:53:52] {1944} INFO -  at 156.5s,	estimator lgbm's best error=0.5733,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:53:52] {1748} INFO - iteration 81, current learner extra_tree
# [flaml.automl: 10-28 13:53:52] {1944} INFO -  at 157.2s,	estimator extra_tree's best error=0.8396,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:53:52] {1748} INFO - iteration 82, current learner rf
# [flaml.automl: 10-28 13:53:53] {1944} INFO -  at 158.1s,	estimator rf's best error=0.9206,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:53:53] {1748} INFO - iteration 83, current learner xgboost
# [flaml.automl: 10-28 13:53:57] {1944} INFO -  at 161.4s,	estimator xgboost's best error=0.6750,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:53:57] {1748} INFO - iteration 84, current learner xgboost
# [flaml.automl: 10-28 13:53:58] {1944} INFO -  at 162.8s,	estimator xgboost's best error=0.6750,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:53:58] {1748} INFO - iteration 85, current learner xgboost
# [flaml.automl: 10-28 13:54:03] {1944} INFO -  at 167.7s,	estimator xgboost's best error=0.6750,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:54:03] {1748} INFO - iteration 86, current learner xgboost
# [flaml.automl: 10-28 13:54:04] {1944} INFO -  at 168.3s,	estimator xgboost's best error=0.6750,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:54:04] {1748} INFO - iteration 87, current learner xgboost
# [flaml.automl: 10-28 13:54:15] {1944} INFO -  at 180.2s,	estimator xgboost's best error=0.6750,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:54:15] {1748} INFO - iteration 88, current learner lgbm
# [flaml.automl: 10-28 13:54:22] {1944} INFO -  at 186.8s,	estimator lgbm's best error=0.5733,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:54:22] {1748} INFO - iteration 89, current learner lgbm
# [flaml.automl: 10-28 13:54:55] {1944} INFO -  at 220.3s,	estimator lgbm's best error=0.5733,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:54:55] {1748} INFO - iteration 90, current learner extra_tree
# [flaml.automl: 10-28 13:54:57] {1944} INFO -  at 221.7s,	estimator extra_tree's best error=0.8222,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:54:57] {1748} INFO - iteration 91, current learner xgboost
# [flaml.automl: 10-28 13:55:02] {1944} INFO -  at 226.5s,	estimator xgboost's best error=0.6091,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:55:02] {1748} INFO - iteration 92, current learner extra_tree
# [flaml.automl: 10-28 13:55:03] {1944} INFO -  at 227.3s,	estimator extra_tree's best error=0.8222,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:55:03] {1748} INFO - iteration 93, current learner xgboost
# [flaml.automl: 10-28 13:55:05] {1944} INFO -  at 230.1s,	estimator xgboost's best error=0.6091,	best estimator lgbm's best error=0.5733
# [flaml.automl: 10-28 13:55:05] {1748} INFO - iteration 94, current learner xgboost
# [flaml.automl: 10-28 13:55:14] {1944} INFO -  at 238.8s,	estimator xgboost's best error=0.5682,	best estimator xgboost's best error=0.5682
# [flaml.automl: 10-28 13:55:14] {1748} INFO - iteration 95, current learner lgbm
# [flaml.automl: 10-28 13:55:22] {1944} INFO -  at 246.6s,	estimator lgbm's best error=0.5733,	best estimator xgboost's best error=0.5682
# [flaml.automl: 10-28 13:55:22] {1748} INFO - iteration 96, current learner extra_tree
# [flaml.automl: 10-28 13:55:24] {1944} INFO -  at 248.7s,	estimator extra_tree's best error=0.8220,	best estimator xgboost's best error=0.5682
# [flaml.automl: 10-28 13:55:24] {1748} INFO - iteration 97, current learner xgboost
# [flaml.automl: 10-28 13:55:26] {1944} INFO -  at 250.5s,	estimator xgboost's best error=0.5682,	best estimator xgboost's best error=0.5682
# [flaml.automl: 10-28 13:55:26] {1748} INFO - iteration 98, current learner xgboost
# [flaml.automl: 10-28 13:56:17] {1944} INFO -  at 302.0s,	estimator xgboost's best error=0.5421,	best estimator xgboost's best error=0.5421
# [flaml.automl: 10-28 13:56:17] {1748} INFO - iteration 99, current learner rf
# [flaml.automl: 10-28 13:56:18] {1944} INFO -  at 302.6s,	estimator rf's best error=0.9206,	best estimator xgboost's best error=0.5421
# [flaml.automl: 10-28 13:56:18] {1748} INFO - iteration 100, current learner lgbm
# [flaml.automl: 10-28 13:56:40] {1944} INFO -  at 324.8s,	estimator lgbm's best error=0.5196,	best estimator lgbm's best error=0.5196
# [flaml.automl: 10-28 13:56:40] {1748} INFO - iteration 101, current learner xgboost
# [flaml.automl: 10-28 13:57:19] {1944} INFO -  at 364.0s,	estimator xgboost's best error=0.5421,	best estimator lgbm's best error=0.5196
# [flaml.automl: 10-28 13:57:19] {1748} INFO - iteration 102, current learner rf
# [flaml.automl: 10-28 13:57:21] {1944} INFO -  at 365.9s,	estimator rf's best error=0.8831,	best estimator lgbm's best error=0.5196
# [flaml.automl: 10-28 13:57:21] {1748} INFO - iteration 103, current learner lgbm
# [flaml.automl: 10-28 13:57:48] {1944} INFO -  at 393.0s,	estimator lgbm's best error=0.5196,	best estimator lgbm's best error=0.5196
# [flaml.automl: 10-28 13:57:48] {1748} INFO - iteration 104, current learner rf
# [flaml.automl: 10-28 13:57:49] {1944} INFO -  at 394.0s,	estimator rf's best error=0.8831,	best estimator lgbm's best error=0.5196
# [flaml.automl: 10-28 13:57:49] {1748} INFO - iteration 105, current learner lgbm
# [flaml.automl: 10-28 13:58:12] {1944} INFO -  at 416.4s,	estimator lgbm's best error=0.5196,	best estimator lgbm's best error=0.5196
# [flaml.automl: 10-28 13:58:12] {1748} INFO - iteration 106, current learner rf
# [flaml.automl: 10-28 13:58:14] {1944} INFO -  at 418.9s,	estimator rf's best error=0.8798,	best estimator lgbm's best error=0.5196
# [flaml.automl: 10-28 13:58:14] {1748} INFO - iteration 107, current learner xgboost
# [flaml.automl: 10-28 13:58:31] {1944} INFO -  at 436.1s,	estimator xgboost's best error=0.5421,	best estimator lgbm's best error=0.5196
# [flaml.automl: 10-28 13:58:31] {1748} INFO - iteration 108, current learner lgbm
# [flaml.automl: 10-28 14:00:29] {1944} INFO -  at 554.2s,	estimator lgbm's best error=0.4989,	best estimator lgbm's best error=0.4989
# [flaml.automl: 10-28 14:00:29] {1748} INFO - iteration 109, current learner xgboost
# [flaml.automl: 10-28 14:01:59] {1944} INFO -  at 644.0s,	estimator xgboost's best error=0.5321,	best estimator lgbm's best error=0.4989
# [flaml.automl: 10-28 14:01:59] {1748} INFO - iteration 110, current learner rf
# [flaml.automl: 10-28 14:02:01] {1944} INFO -  at 645.7s,	estimator rf's best error=0.8789,	best estimator lgbm's best error=0.4989
# [flaml.automl: 10-28 14:02:01] {1748} INFO - iteration 111, current learner lgbm
# [flaml.automl: 10-28 14:02:23] {1944} INFO -  at 668.1s,	estimator lgbm's best error=0.4989,	best estimator lgbm's best error=0.4989
# [flaml.automl: 10-28 14:02:23] {1748} INFO - iteration 112, current learner xgboost
# [flaml.automl: 10-28 14:03:02] {1944} INFO -  at 706.4s,	estimator xgboost's best error=0.5078,	best estimator lgbm's best error=0.4989
# [flaml.automl: 10-28 14:03:02] {1748} INFO - iteration 113, current learner xgboost
# [flaml.automl: 10-28 14:07:30] {1944} INFO -  at 974.4s,	estimator xgboost's best error=0.5078,	best estimator lgbm's best error=0.4989
# [flaml.automl: 10-28 14:07:30] {1748} INFO - iteration 114, current learner extra_tree
# [flaml.automl: 10-28 14:07:32] {1944} INFO -  at 976.4s,	estimator extra_tree's best error=0.8220,	best estimator lgbm's best error=0.4989
# [flaml.automl: 10-28 14:07:32] {1748} INFO - iteration 115, current learner lgbm
# [flaml.automl: 10-28 14:11:56] {1944} INFO -  at 1240.5s,	estimator lgbm's best error=0.4873,	best estimator lgbm's best error=0.4873
# [flaml.automl: 10-28 14:11:56] {1748} INFO - iteration 116, current learner lgbm
# [flaml.automl: 10-28 14:13:56] {1944} INFO -  at 1360.4s,	estimator lgbm's best error=0.4873,	best estimator lgbm's best error=0.4873
# [flaml.automl: 10-28 14:13:56] {1748} INFO - iteration 117, current learner xgboost
# [flaml.automl: 10-28 14:14:49] {1944} INFO -  at 1414.2s,	estimator xgboost's best error=0.4340,	best estimator xgboost's best error=0.4340
# [flaml.automl: 10-28 14:14:49] {1748} INFO - iteration 118, current learner xgboost
# [flaml.automl: 10-28 14:16:11] {1944} INFO -  at 1495.7s,	estimator xgboost's best error=0.4100,	best estimator xgboost's best error=0.4100
# [flaml.automl: 10-28 14:16:11] {1748} INFO - iteration 119, current learner catboost
# [flaml.automl: 10-28 14:16:14] {1944} INFO -  at 1498.4s,	estimator catboost's best error=0.9331,	best estimator xgboost's best error=0.4100
# [flaml.automl: 10-28 14:16:14] {1748} INFO - iteration 120, current learner xgboost
# [flaml.automl: 10-28 14:17:09] {1944} INFO -  at 1553.5s,	estimator xgboost's best error=0.4100,	best estimator xgboost's best error=0.4100
# [flaml.automl: 10-28 14:17:09] {1748} INFO - iteration 121, current learner xgboost
# [flaml.automl: 10-28 14:19:31] {1944} INFO -  at 1695.5s,	estimator xgboost's best error=0.4100,	best estimator xgboost's best error=0.4100
# [flaml.automl: 10-28 14:19:31] {1748} INFO - iteration 122, current learner xgboost
# [flaml.automl: 10-28 14:20:31] {1944} INFO -  at 1755.6s,	estimator xgboost's best error=0.4100,	best estimator xgboost's best error=0.4100
# [flaml.automl: 10-28 14:20:31] {1748} INFO - iteration 123, current learner xgboost
# [flaml.automl: 10-28 14:20:51] {1944} INFO -  at 1776.1s,	estimator xgboost's best error=0.4100,	best estimator xgboost's best error=0.4100
# [flaml.automl: 10-28 14:20:51] {1748} INFO - iteration 124, current learner rf
# [flaml.automl: 10-28 14:20:54] {1944} INFO -  at 1778.7s,	estimator rf's best error=0.8789,	best estimator xgboost's best error=0.4100
# [flaml.automl: 10-28 14:20:54] {1748} INFO - iteration 125, current learner lgbm
# [flaml.automl: 10-28 14:34:38] {1944} INFO -  at 2603.2s,	estimator lgbm's best error=0.4659,	best estimator xgboost's best error=0.4100
# [flaml.automl: 10-28 14:34:38] {1748} INFO - iteration 126, current learner lgbm
# [flaml.automl: 10-28 14:39:09] {1944} INFO -  at 2874.2s,	estimator lgbm's best error=0.4659,	best estimator xgboost's best error=0.4100
# [flaml.automl: 10-28 14:39:09] {1748} INFO - iteration 127, current learner lgbm
# [flaml.automl: 10-28 14:43:29] {1944} INFO -  at 3134.2s,	estimator lgbm's best error=0.4659,	best estimator xgboost's best error=0.4100
# [flaml.automl: 10-28 14:43:29] {1748} INFO - iteration 128, current learner catboost
# [flaml.automl: 10-28 14:43:31] {1944} INFO -  at 3135.4s,	estimator catboost's best error=0.9331,	best estimator xgboost's best error=0.4100
# [flaml.automl: 10-28 14:43:31] {1748} INFO - iteration 129, current learner xgboost
# [flaml.automl: 10-28 14:49:25] {1944} INFO -  at 3489.8s,	estimator xgboost's best error=0.3913,	best estimator xgboost's best error=0.3913
# [flaml.automl: 10-28 14:49:25] {1748} INFO - iteration 130, current learner xgboost
# [flaml.automl: 10-28 14:55:26] {1944} INFO -  at 3850.4s,	estimator xgboost's best error=0.3913,	best estimator xgboost's best error=0.3913
# [flaml.automl: 10-28 14:55:26] {1748} INFO - iteration 131, current learner xgboost
# [flaml.automl: 10-28 14:58:41] {1944} INFO -  at 4046.0s,	estimator xgboost's best error=0.3913,	best estimator xgboost's best error=0.3913
# [flaml.automl: 10-28 14:58:41] {1748} INFO - iteration 132, current learner xgboost

# %%
# import pickle
# with open("./data/flaml_automl_best.pkl", "wb") as f:
#     pickle.dump(automl, f, pickle.HIGHEST_PROTOCOL)

# %%
# # from flaml import AutoML

# # time_budget = 2 * 3600
# # automl = AutoML()
# automl_settings = {
#     "time_budget": time_budget,  # in seconds
#     "metric": metric,
#     "task": "regression",
#     "log_file_name": f"flaml_{time_budget}_nf20211007_{metric}.log",
# }
